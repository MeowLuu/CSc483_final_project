# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OrdinalEncoder
import json
import pandas as pd

# %%
with open("yelp_dataset/yelp_academic_dataset_business.json", "r") as f:
    business_data = pd.read_json(f, lines=True)
    print(business_data)
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2                  5255 E Broadway Blvd         Tucson    AZ       85711
# 3                           935 Race St   Philadelphia    PA       19107
# 4                         101 Walnut St     Green Lane    PA       18054
# ...                                 ...            ...   ...         ...
# 150341                3388 Gateway Blvd       Edmonton    AB     T6J 5H2
# 150342               2813 Bransford Ave      Nashville    TN       37204
# 150343           6020 E 82nd St, Ste 46   Indianapolis    IN       46250
# 150344                     2472 Troy Rd   Edwardsville    IL       62025
# 150345            238 Apollo Beach Blvd   Apollo beach    FL       33572
#
#          latitude   longitude  stars  review_count  is_open  \
# 0       34.426679 -119.711197    5.0             7        0
# 1       38.551126  -90.335695    3.0            15        1
# 2       32.223236 -110.880452    3.5            22        0
# 3       39.955505  -75.155564    4.0            80        1
# 4       40.338183  -75.471659    4.5            13        1
# ...           ...         ...    ...           ...      ...
# 150341  53.468419 -113.492054    3.0            13        1
# 150342  36.115118  -86.766925    4.0             5        1
# 150343  39.908707  -86.065088    3.5             8        1
# 150344  38.782351  -89.950558    4.0            24        1
# 150345  27.771002  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 1                  {'BusinessAcceptsCreditCards': 'True'}
# 2       {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# ...                                                   ...
# 150341  {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 150342  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 150343  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 150344  {'BusinessParking': '{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 1       Shipping Centers, Local Services, Notaries, Ma...
# 2       Department Stores, Shopping, Fashion, Home & G...
# 3       Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                               Brewpubs, Breweries, Food
# ...                                                   ...
# 150341                         Nail Salons, Beauty & Spas
# 150342  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 150343  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                    None
# 1       {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2       {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# ...                                                   ...
# 150341  {'Monday': '10:0-19:30', 'Tuesday': '10:0-19:3...
# 150342  {'Monday': '9:30-17:30', 'Tuesday': '9:30-17:3...
# 150343                                               None
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [150346 rows x 14 columns]

# %%
with open("yelp_dataset/yelp_academic_dataset_user.json", "r") as f:
    user_data_list = []
    CHUNK_SIZE = 100000
    TOTAL = 2000000
    user_data_reader = pd.read_json(f, lines=True, chunksize=CHUNK_SIZE)
    for i, chunk in enumerate(user_data_reader):
        if i*CHUNK_SIZE == TOTAL:
            print("Operation successful")
            break
        user_data_list.append(chunk)
        print("Processed chunk " + str(i+1) + " of " + str(CHUNK_SIZE) + " users")
# Out:
# Processed chunk 1 of 100000 users
# Processed chunk 2 of 100000 users
# Processed chunk 3 of 100000 users
# Processed chunk 4 of 100000 users
# Processed chunk 5 of 100000 users
# Processed chunk 6 of 100000 users
# Processed chunk 7 of 100000 users
# Processed chunk 8 of 100000 users
# Processed chunk 9 of 100000 users
# Processed chunk 10 of 100000 users
# Processed chunk 11 of 100000 users
# Processed chunk 12 of 100000 users
# Processed chunk 13 of 100000 users
# Processed chunk 14 of 100000 users
# Processed chunk 15 of 100000 users
# Processed chunk 16 of 100000 users
# Processed chunk 17 of 100000 users
# Processed chunk 18 of 100000 users
# Processed chunk 19 of 100000 users
# Processed chunk 20 of 100000 users

# %%
user_data = pd.concat(user_data_list).sort_index()
user_data
# Out:
#                         user_id     name  review_count        yelping_since  \
# 0        qVc8ODYU5SZjKXVBgXdI7w   Walker           585  2007-01-25 16:47:26
# 1        j14WgRoU_-2ZE1aw1dXrJg   Daniel          4333  2009-01-25 04:35:42
# 2        2WnXYQFK0hXEoTxPtV2zvg    Steph           665  2008-07-25 10:41:00
# 3        SZDeASXq7o05mMNLshsdIA     Gwen           224  2005-11-29 04:38:33
# 4        hA5lMy-EnncsH4JoR-hFGQ    Karen            79  2007-01-05 19:40:59
# ...                         ...      ...           ...                  ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw  Jerrold            23  2015-01-06 00:31:31
# 1987893  68czcr4BxJyMQ9cJBm6C7Q     Jane             1  2016-06-14 07:20:52
# 1987894  1x3KMskYxOuJCjRz70xOqQ  Shomari             4  2017-02-04 15:31:58
# 1987895  ulfGl4tdbrH05xKzh5lnog  Susanne             2  2011-01-14 00:29:08
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA      Isa             2  2020-12-19 02:32:39
#
#          useful  funny   cool  \
# 0          7217   1259   5994
# 1         43091  13066  27281
# 2          2086   1010   1003
# 3           512    330    299
# 4            29     15      7
# ...         ...    ...    ...
# 1987892       7      0      0
# 1987893       0      0      0
# 1987894       1      1      0
# 1987895       0      0      0
# 1987896       0      0      0
#
#                                                      elite  \
# 0                                                     2007
# 1        2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2                                 2009,2010,2011,2012,2013
# 3                                           2009,2010,2011
# 4
# ...                                                    ...
# 1987892
# 1987893
# 1987894
# 1987895
# 1987896
#
#                                                    friends  fans  ...  \
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138  ...
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52  ...
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28  ...
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1  ...
# ...                                                    ...   ...  ...
# 1987892                                               None     0  ...
# 1987893                                               None     0  ...
# 1987894                                               None     0  ...
# 1987895                                               None     0  ...
# 1987896                                               None     0  ...
#
#          compliment_more  compliment_profile  compliment_cute  \
# 0                     65                  55               56
# 1                    264                 184              157
# 2                     13                  10               17
# 3                      4                   1                6
# 4                      1                   0                0
# ...                  ...                 ...              ...
# 1987892                0                   0                0
# 1987893                0                   0                0
# 1987894                0                   0                0
# 1987895                0                   0                0
# 1987896                0                   0                0
#
#          compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0                     18              232               844              467
# 1                    251             1847              7054             3131
# 2                      3               66                96              119
# 3                      2               12                16               26
# 4                      0                1                 1                0
# ...                  ...              ...               ...              ...
# 1987892                0                0                 0                0
# 1987893                0                0                 0                0
# 1987894                0                0                 0                0
# 1987895                0                0                 0                0
# 1987896                0                0                 0                0
#
#          compliment_funny  compliment_writer  compliment_photos
# 0                     467                239                180
# 1                    3131               1521               1946
# 2                     119                 35                 18
# 3                      26                 10                  9
# 4                       0                  0                  0
# ...                   ...                ...                ...
# 1987892                 0                  0                  0
# 1987893                 0                  0                  0
# 1987894                 0                  0                  0
# 1987895                 0                  0                  0
# 1987896                 0                  0                  0
#
# [1987897 rows x 22 columns]

# %%
with open("yelp_dataset/yelp_academic_dataset_review.json", "r") as f:
    review_data_list = []
    CHUNK_SIZE = 100000
    TOTAL = 2000000
    review_data_reader = pd.read_json(f, lines=True, chunksize=CHUNK_SIZE)
    for i, chunk in enumerate(review_data_reader):
        if i*CHUNK_SIZE == TOTAL:
            print("Operation successful")
            break
        review_data_list.append(chunk)
        print("Processed chunk " + str(i+1) + " of " + str(CHUNK_SIZE) + " reviews")
# Out:
# Processed chunk 1 of 100000 reviews
# Processed chunk 2 of 100000 reviews
# Processed chunk 3 of 100000 reviews
# Processed chunk 4 of 100000 reviews
# Processed chunk 5 of 100000 reviews
# Processed chunk 6 of 100000 reviews
# Processed chunk 7 of 100000 reviews
# Processed chunk 8 of 100000 reviews
# Processed chunk 9 of 100000 reviews
# Processed chunk 10 of 100000 reviews
# Processed chunk 11 of 100000 reviews
# Processed chunk 12 of 100000 reviews
# Processed chunk 13 of 100000 reviews
# Processed chunk 14 of 100000 reviews
# Processed chunk 15 of 100000 reviews
# Processed chunk 16 of 100000 reviews
# Processed chunk 17 of 100000 reviews
# Processed chunk 18 of 100000 reviews
# Processed chunk 19 of 100000 reviews
# Processed chunk 20 of 100000 reviews
# Operation successful

# %%
review_data = pd.concat(review_data_list).sort_index()
review_data
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 1999995  5Kj5gEHBP8SIYeiwaNV9xg  Ux0CsHDQvEbtZXlGDgcCHg
# 1999996  wQq7vGWf8euzUk7TkoVAXw  5jKScvMqxW_rzd0D8xgX1A
# 1999997  eAKeO7EX8kSKsCBcq7mKTA  _Redmmq2oiUvMFhzS-CAVA
# 1999998  HaY4k2iVPhcTOwfGVPlYSg  BnMfYA-c2YQbzVMto2wO5w
# 1999999  MmFruENWfbqghG5hwJhIaw  p465OiphoWkYQDnbK_hLIg
#
#                     business_id  stars  useful  funny  cool  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1        7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2        YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# 3        kxX2SOes4o-D3ZQBkiMRfA      5       1      0     1
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4       1      0     1
# ...                         ...    ...     ...    ...   ...
# 1999995  TGiTwNYy3ZvOoHTT7ZHpgg      1       0      0     0
# 1999996  kOmhn5Eo6AWzMVL6ALRq2Q      5       2      0     1
# 1999997  m6ZcOrHJHYmIPhjgh8cycw      2       0      0     0
# 1999998  YCfMNP_1YCTXTKlrnw44vQ      5       0      0     0
# 1999999  YceIYPMBP3oKcuEFhj2_Gg      5       0      0     0
#
#                                                       text                date
# 0        If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1        I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2        Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3        Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4        Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# ...                                                    ...                 ...
# 1999995  Had to wait over 20 minutes for my order, then... 2020-09-20 00:13:27
# 1999996  Very good food!! My wife and I got crab legs, ... 2020-06-11 23:25:17
# 1999997  Food was just ok, nothing to write home about.... 2020-12-02 23:02:55
# 1999998  Great spot!   Food and service was terrific!  ... 2021-01-09 02:45:57
# 1999999  My ten-year-old Sheltie, Diane, had a severe l... 2020-12-04 22:23:55
#
# [2000000 rows x 9 columns]

# %%
categories = []
for category in business_data['categories']:
    if category is not None:
        for c in category.split(','):
            c = c.strip()
            if c not in categories:
                categories.append(c)
print(categories)
# Out:
# ['Doctors', 'Traditional Chinese Medicine', 'Naturopathic/Holistic', 'Acupuncture', 'Health & Medical', 'Nutritionists', 'Shipping Centers', 'Local Services', 'Notaries', 'Mailbox Centers', 'Printing Services', 'Department Stores', 'Shopping', 'Fashion', 'Home & Garden', 'Electronics', 'Furniture Stores', 'Restaurants', 'Food', 'Bubble Tea', 'Coffee & Tea', 'Bakeries', 'Brewpubs', 'Breweries', 'Burgers', 'Fast Food', 'Sandwiches', 'Ice Cream & Frozen Yogurt', 'Sporting Goods', 'Shoe Stores', 'Sports Wear', 'Accessories', 'Synagogues', 'Religious Organizations', 'Pubs', 'Italian', 'Bars', 'American (Traditional)', 'Nightlife', 'Greek', 'Vietnamese', 'Food Trucks', 'Diners', 'Breakfast & Brunch', 'General Dentistry', 'Dentists', 'Cosmetic Dentists', 'Delis', 'Sushi Bars', 'Japanese', 'Automotive', 'Auto Parts & Supplies', 'Auto Customization', 'Vape Shops', 'Tobacco Shops', 'Personal Shopping', 'Vitamins & Supplements', 'Car Rental', 'Hotels & Travel', 'Truck Rental', 'Korean', 'Cafes', 'Wine Bars', 'Books', 'Mags', 'Music & Video', 'Bookstores', 'Steakhouses', 'Asian Fusion', 'Hot Dogs', 'Pet Services', 'Pet Groomers', 'Pets', 'Veterinarians', "Women's Clothing", "Children's Clothing", "Men's Clothing", 'Adult', 'Seafood', 'Cocktail Bars', 'Pizza', 'Chicken Wings', 'Trampoline Parks', 'Active Life', 'Salad', 'Soup', 'Dance Wear', 'Arts & Entertainment', 'Social Clubs', 'Performing Arts', 'Event Planning & Services', 'Hotels', 'Eatertainment', 'Mobile Phones', 'Telecommunications', 'Mobile Phone Accessories', 'IT Services & Computer Repair', 'Museums', 'Kids Activities', 'Education', 'Playgrounds', "Children's Museums", 'Musicians', 'DJs', 'Karaoke', 'Hair Salons', 'Hair Extensions', 'Beauty & Spas', 'Wigs', 'Specialty Food', 'Pasta Shops', 'DUI Law', 'Professional Services', 'Lawyers', 'Criminal Defense Law', 'Laser Hair Removal', 'Hair Removal', 'Chiropractors', 'Weight Loss Centers', 'Sports Medicine', 'Medical Spas', 'Skin Care', 'Candle Stores', 'Home Decor', 'Chinese', 'Music Venues', 'Internet Service Providers', 'Jazz & Blues', 'Internet Cafes', 'Caterers', 'Fitness & Instruction', 'Trainers', 'Gyms', 'Yoga', 'Real Estate Agents', 'Home Services', 'Real Estate', 'Health Markets', 'Pet Adoption', 'Grocery', 'Convenience Stores', 'Juice Bars & Smoothies', 'Ophthalmologists', 'Eyewear & Opticians', 'Optometrists', 'American (New)', 'Sports Bars', 'Gastropubs', 'Beer Bar', 'Uniforms', 'Tours', 'Local Flavor', 'Appliances & Repair', 'Towing', 'Motorcycle Rental', 'Motorcycle Gear', 'Chocolatiers & Shops', 'Candy Stores', 'Baby Gear & Furniture', 'Banks & Credit Unions', 'Financial Services', 'Personal Care Services', 'Massage', 'Nail Salons', 'Tabletop Games', 'Lounges', 'Wraps', 'Festivals', 'Beer', 'Wine & Spirits', 'Gas Stations', 'Keys & Locksmiths', 'Pet Sitting', 'Venues & Event Spaces', 'Fruits & Veggies', 'Antiques', 'Body Shops', 'Masonry/Concrete', 'Gardeners', 'Lawn Services', 'Tree Services', 'Landscape Architects', 'Contractors', 'Landscaping', 'Party & Event Planning', 'Mortgage Brokers', 'Mortgage Lenders', 'Physical Therapy', 'Jewelry', 'Cajun/Creole', 'Mexican', 'Couriers & Delivery Services', 'French', 'Moroccan', 'Mediterranean', 'Flooring', 'Handyman', 'Pest Control', 'Auction Houses', 'Beer Gardens', 'Wine Tours', 'Beer Tours', 'Drugstores', 'Discount Store', 'Public Services & Government', 'Libraries', 'Flowers & Gifts', 'Embroidery & Crochet', 'Arts & Crafts', 'Gift Shops', 'Food Delivery Services', 'Parenting Classes', 'Maternity Wear', 'Specialty Schools', 'Laundry Services', 'Child Care & Day Care', 'Barbers', 'Glass & Mirrors', 'Door Sales/Installation', 'Hardware Stores', 'Hot Tub & Pool', 'Pool & Hot Tub Service', 'Tires', 'Auto Repair', 'Oil Change Stations', 'Medical Centers', 'Diagnostic Services', 'Orthopedists', 'Spine Surgeons', 'Diagnostic Imaging', 'Custom Cakes', 'Desserts', 'Cupcakes', 'Car Wash', 'Auto Detailing', 'Pain Management', 'Osteopathic Physicians', 'Title Loans', 'Installment  ...

# %%
def test_get_category(user_query: str) -> str:
    # NOTE: Work in progress (not used in project) -- getting category accurately without vector similarity
    import itertools
    user_query = user_query.lower()
    category_words = [word.lower().replace('(', '').replace(')', '') for word in set(word for category in categories for word in category.split()) - {'&'}]
    query = {word : [] for word in user_query.split()}
    for query_word in user_query.split():
        temp = {word : edit_distance(query_word, word) for word in category_words}
        for i, word in enumerate(sorted(temp, key=temp.get)):
            if i == 10:
                break
            if len(query[query_word]) >= 1 and temp[query[query_word][0]] < temp[word]:
                continue
            query[query_word].append(word)
    print(query)
    for combination in list(itertools.product(*list(query.values()))):
        for category in categories:
            identical_matches = []
            if set(combination).issubset(set([word.lower() for word in category.split()])):
                identical_matches.append(category)
            if identical_matches != []:
                print(identical_matches)
                return min(identical_matches, key=lambda x : len(x.split()))
    fractions = {}
    
            
#test_get_category('yelp')

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# NOTE: run pip install sentence-transformers transformers scikit-learn as an admin on terminal before running this

model = SentenceTransformer('bert-base-nli-mean-tokens')

def calculate_similarity(query, dataset):
    query_embedding = model.encode([query])
    similarities = []

    for item in dataset:
        item_embedding = model.encode([item])
        similarity = cosine_similarity(query_embedding, item_embedding)[0][0]
        similarities.append((item, similarity))

    # Sort by similarity in descending order, i.e the most relevant categories at the front
    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities

# %%
user_ids = user_data['user_id'].values.tolist()
user_ids
# Out:
# ['qVc8ODYU5SZjKXVBgXdI7w',
#  'j14WgRoU_-2ZE1aw1dXrJg',
#  '2WnXYQFK0hXEoTxPtV2zvg',
#  'SZDeASXq7o05mMNLshsdIA',
#  'hA5lMy-EnncsH4JoR-hFGQ',
#  'q_QQ5kBBwlCcbL1s4NVK3g',
#  'cxuxXkcihfCbqt5Byrup8Q',
#  'E9kcWJdJUHuTKfQurPljwA',
#  'lO1iq-f75hnPNZkTy3Zerg',
#  'AUi8MPWJ0mLkMfwbui27lg',
#  'iYzhPPqnrjJkg1JHZyMhzA',
#  'xoZvMJPDW6Q9pDAXI0e_Ww',
#  'vVukUtqoLF5BvH_VtQFNoA',
#  '_crIokUeTCHVK_JVOy-0qQ',
#  '1McG5Rn_UDkmlkZOrsdptg',
#  'SgiBkhXeqIKl1PlFpZOycQ',
#  'fJZO_skqpnhk1kvomI4dmA',
#  'x7YtLnBW2dUnrrpwaofVQQ',
#  'QF1Kuhs8iwLWANNZxebTow',
#  'VcLRGCG_VbAo8MxOm76jzA',
#  '1L3O2CUTk27SnmqyPBWQdQ',
#  'v7DwnrjzuTk7pXmuBPZnsg',
#  'FT9CFS39sjZxVjCTrDHmdg',
#  'MGPQVLsODMm9ZtYQW-g_OA',
#  'OlJ9vcVFB1iEKcZO-MS3cQ',
#  'wAw9FHMiOZd9ROoc5x4DpQ',
#  'kggqL33iZjeHmUn1Rtdjzg',
#  'wrNOKq0hOlz8q1N_YCNXCA',
#  '4F0IjrUJGAieoWwHnRhIJw',
#  '4ZaqBJqt7laPPs8xfWvr6A',
#  'zjPbmmvO4QzE_nE9uErLTg',
#  '65uUyG9yuF0rdMh0z7ajaA',
#  'NIhcRW6DWvk1JQhDhXwgOQ',
#  'aF3mEXDJuILmeF-9PcxAsQ',
#  'baSDvZweZk6qLY_kHPvYzQ',
#  'XLs_PhrJ7Qwn_RfgMM7Djw',
#  'rppTTi-kfF8-qyiArNemag',
#  'KYBEVBAP7QUlt1LjmatTJg',
#  'QJI9OSEn6ujRCtrX06vs1w',
#  'AkBtT43dYcttxQ3qOzPBAg',
#  'KXZ8A8h7Q9ZJRU5TM9asjw',
#  '5cVgAicAhCTSrKzsKDuTdw',
#  'HoiOETUtwO4CL0PhjDCnSw',
#  'rCedFOnskGvHQTprtA4-5g',
#  'sgCZmOkdHBiaKaE6ZKVBaA',
#  'yzonmWerCPxEI3ROuk6caA',
#  'bNJmIcxc_FRWxftI_vhpbg',
#  '2Yw9-N2VYZFqg2ylhpb8NA',
#  'og-Pb8auVwO-BA_-4TnK9Q',
#  'RDTVzWPoCeGaUujrHIWRBQ',
#  'IpLRJY4CP3fXtlEd8Y4GFQ',
#  'hluQms-QLpaqZASKlDCJHw',
#  'qsHZ6_yT870pmm4Oxvw5Og',
#  'ZIR96Kh35GvW2eLyQHJh1Q',
#  'N4Y2GiUxnQOvUUHtFyayKg',
#  '2l0O1EI1m0yWjFo2zSt71w',
#  'RgDVC3ZUBqpEe6Y1kPhIpw',
#  'V6PeLHJ8D1C7utl4HzjBmg',
#  'OmjMNG77obZOKQ59o-Tx4Q',
#  'B-OVAq7aQN1aPN3NiFekTg',
#  'LwZJFLGxQwjjeOgpqTJnfw',
#  'lquc6IF6uGIeRomDLu9UnA',
#  'M7giQhu5iK0ESOoZi3gpfQ',
#  '3oDIaMM1bd7cwN0eKQv-rA',
#  'X7SwvRrnsZ8I3bEPGELpnQ',
#  'YuRfPsIME6v5qYr3GfFzrg',
#  'mqc6fRbm5ZBBl4J3203ctQ',
#  'n8bbgZJLENE4dC4E743ukQ',
#  '-TT5e-YQU9xLb1JAGCGkQw',
#  'q7iWal_rXNSHkHeCMMvZxQ',
#  '0juMoWXC7z4c7LgQP2s3sA',
#  'vOUs1d2gsVGDkdH7_fKgMQ',
#  'OJorsQjotS1dIv--IVifCA',
#  'KxrKVxdXGkfMJ9XwJZzoLQ',
#  'VHdY6oG2JPVNjihWhOooAQ',
#  'eqS5lpxVMEzS_xaGP8NW_w',
#  'zx2NykkcJd1vdOgoS_ZhjQ',
#  'MRQL87mqMrLgLBNYE97ahg',
#  'YJ6S9R50pE0FsSDn3Z8j2g',
#  'ov9G-Mn1XGFp6m8sFEmEng',
#  'LbPkYMGmsu4snHkY-Ri1ww',
#  '3xrb0LpbaJ24Pkdyd55U8Q',
#  'om5ZiponkpRqUNa3pVPiRg',
#  'K7thO1n-vZ9PFYiC7nTR2w',
#  'lRTLBbMLzDrnuAdEVSLrqA',
#  'asAdx4Q3cAMykgPgtQt6cg',
#  '08VTr9hyJikxfimhk78jbg',
#  'c7XI431TnC9_AkmC-qrXvQ',
#  '8cRfVboGSLA_yc94mBwY-w',
#  'PZE8NFD4XYMejKLFJm47bw',
#  'uVtkixXCP7LXRpC1EedGpA',
#  'IVz8D3L33io-7Bp3NTo8Pw',
#  'd9WIz0Xuh9ECkHfVmqbhIw',
#  'Y4DBgQUuecjUc7KGtWUVvA',
#  'HmN7p502YMJGkBNv5bzi1w',
#  '8m2LgacB5VeP_1Mn5ZMC4w',
#  'MvOXPiqRr9IjqVtwC5mUNA',
#  'PrJ37Ik9DxritxGPqI9ktw',
#  'dHLL7SVGJw5uM6IEp_wb4Q',
#  'UQFE3BT1rsIYrcDvu_XVow',
#  'hSMVQ7MSh6B0OgPxFQFO8g',
#  'MPQ5-SkAcPW5_uLn-7_jCw',
#  'jh-yu1Ap3TAwDS1ko6eqhg',
#  'jVYzrVblDFSuL3GHtt8ZSA',
#  'w-zD8Ln3XZszM82AfVrspg',
#  '3zxy3LVBV3ttxoYbY4rQ8A',
#  'bF2xmRxR_eyJ-HRs-ClOmw',
#  'qqOcmpUctU-Zn_DxhgW-Vw',
#  'Axd4L6VSBZ6QkHtqJAeCaw',
#  'KrIL3TIOJI-tjvU6BlcA-g',
#  '2mdlIKeLV04q_wcPqNvRWA',
#  'I7YQFiIsO82eliq8nqsLfA',
#  'yOwqfhtwO6q-6gzEhL1meg',
#  'NF7_K38Hc6G4R3hvEhT0dw',
#  'FlhZYUEhfpfm0Ynxacftwg',
#  'l4F2AnWqg3AibuQBN-tYcA',
#  'gRL9s6ENxV1qermRYDWjPQ',
#  '0G-QF457q_0Z_jKqh6xWiA',
#  '1_pwoHx0CjDwfSAI7jRpzQ',
#  'JhBHocI4yDmi2fus7UbKRw',
#  'DgsKBCbBqbFv6dCO_czBIg',
#  'ACkFmmPuBT6rsJ_yxA1DaQ',
#  'MCcz4FmJQaqnIv6pzeS1VQ',
#  '2aYKApNwS5gi1XS_V6qYJg',
#  '6GHPzEmQNTjC7E3P9VF44w',
#  'xwLpDq-rYnyObtBZCD0Wgg',
#  '6aJNIB8yGHDiwrzyxlExRw',
#  'CxpPcC2NCCAj_eXykAFCnA',
#  'xReXrRlxECFpHSS9F5hBCQ',
#  'GPKYStqHcKtNYVLy2PvgoQ',
#  'sHwBXS0trP0CC_f5K_11VA',
#  'C0hNXqJZJuly7et8sSvSAQ',
#  'IxkpteGXdi41e_WuyDxlww',
#  'rwamCBmlGdcdcyRoUcC4kQ',
#  'A5UnAt6EYlDh2PPMpAHV_w',
#  'lNPRvk3WRgsJb-UEJ0J40g',
#  'ITa3vh5ERI90G_WP4SmGUQ',
#  '582iTyqKkoHeBFPMJuQEJw',
#  'iEONL-v4W46yliYsovCP_g',
#  'nDPpFNHBId4o5kjKLpubJg',
#  'g_HiAtI7YBc9rpEhm4qvYg',
#  'DEbiQnC6NsTkddrOm3SF6Q',
#  '2Od6rQYNvPUXQC2Go7vIqg',
#  '_SmK7sPegNCXH-oYR7503A',
#  '2q6LXB2ZR9LiAk0Ltww-Gw',
#  '8zkkuk8KOoNojZhTx0j5KA',
#  'ZhK2xIa4f73JZfua7IP8vA',
#  '4iX1eeMV0VQa7SlN6UXJOw',
#  'Q5jOFJYhIsN8ouJ1rnsLQQ',
#  'N_mkNFTiBCw2bbF_TJY9Ug',
#  'IPzVg0wE9EW2_VfJI0Uzgg',
#  'P3SCIo2ExYs2-eehTNSv4Q',
#  'P5bUL3Engv-2z6kKohB6qQ',
#  'VpREWOjt5Pna6OIgXI9Jcg',
#  'ukCAVNbolx0_gaAkDYZnEA',
#  'qF1V8GyuLL5Fpv40Cyturw',
#  'clirF7pph8EPEoMtvrcj0w',
#  'bQ_qlqlZRFgfRlqveB-ILg',
#  'PadmV2GEoA6mWpQUpPh7Ig',
#  'ouODopBKF3AqfCkuQEnrDg',
#  'M74ZUoNHNOcQp1jJLlt3jA',
#  'CDjeQhhH7ZoSKBDQ5_O3ag',
#  '-RApyq06DMBii7ovXtQnfw',
#  'XvL3WrRN0_3hw0P5tO0J1Q',
#  'bCsS9EJOBTIxRGiqixB5rw',
#  '8Akq8sh1LSmJbqa6Jjxxqg',
#  'YMgZqBUAddmFErxLtCfK_w',
#  'SSp_Idg6Ge-Lb6T99kgKSA',
#  'R67_W_HXmsO-bd872AKw8Q',
#  'Jw4OHr6HibJeEIMfAxc1_Q',
#  'iaDFNFfwwVmc_v3k3_cU1A',
#  'xHzU9LKwxGHq7BNPA16gog',
#  'gYDFiPYFCeY52vvMvvy5Pw',
#  '0kSXMbNFo7mdwTPj4iQv9A',
#  'HzoQKKHDq9BI37dyJAAtGA',
#  '627ihUMdDCxyXw1mOj1MVA',
#  'oW2bCSJ5bIHyRnoZvkHwDg',
#  '8DqQqPnWLMllH2Dd0bETtQ',
#  'JC99U5y-KAchZIjBhf_DiQ',
#  '1ziEzn7BoXTfOQ4YBkdz1Q',
#  'n0Qbz7LaA0r46x-N2gPXxQ',
#  'q-kq52Hm8a5ajWJ_dUlOoA',
#  'qA3AGHIFaNyEd1PRX3QWRg',
#  'cCwig3OI04K4HdOIXpnl_A',
#  'nomP8UcTgKjO6Yu2cLkr3g',
#  '0GNqPGZNPNoTcJ1PFJrexw',
#  'sAb47uEcSjK3uQcylhkhPw',
#  'IjRVv6v8VHqZMoFhmRrXBA',
#  'p1pg5NleZVUO_hcOgiNMmA',
#  'Cy9TCWiOHFvCAl3xiC5vHg',
#  'gjxv-7WqYy_aK1ZAUreBFg',
#  'h8pthOnqCxV94D8-JkZXCQ',
#  'NRrNQ5xHn_7Fu4ctlpKLbQ',
#  'iFreFyM8AcvM38exTtkjpA',
#  'Oqo_AB1BAv4mlPLOWgE-0A',
#  'PmWSamENF-UlNijlB_OckA',
#  'sxYfqtGh_5OuaRoT3d9aAg',
#  'lsCWo9DwJJ7tCRBHNjTsYA',
#  'TDXV6AC5PYOZEyN9eeODfA',
#  'QKbq76KuUHLRZjWXDtbwWQ',
#  'jhuCv6dzRQ6a_kEaDvcrTA',
#  '13f_vtUZEmlzweL91bmVng',
#  '5HGbhAzCXDngWSTckGBtuA',
#  'jpY8IGiem6A7kXfPrFv0PA',
#  'QWxW_pApmpY9iPApC8P-UQ',
#  'Z2pXm4f-2O5ZpMUmXuYK0Q',
#  'S8JD8I-TRR7MoWyKhmw9VQ',
#  '8ZryN_S-n48g6rsa3W3QtQ',
#  'AW0tVcfwYZBiwtwYyaX0WA',
#  '5Z0qHr3lRAy311-D-zo9uQ',
#  'C0RAAI96DJwITSFdioqqUA',
#  'ZMGTBxvz2nfEvZDbXiH_zA',
#  'UVUIi0q38pAvsfuEEppe0Q',
#  'HAAdELyXWv8GPCz183SbvA',
#  '9_3lMnzpm8L92caFU5hH8Q',
#  '4F3DmU8GaO_HHEbgPZ5v4g',
#  'qYhPjTGtXE3DUJBahe85aQ',
#  'OscdJZ1tFY5ybV4Ru5u7JA',
#  'l1K53D1s2BjVXCFGUFYVOA',
#  'ZQWmua4kX75pcd1QB8Nk2g',
#  'Fu8D01UpP5DNnaI7dP9xEw',
#  'eUjJ0SDe6eBoZB7iKYifnw',
#  'BvPQDTs67bcDLWfPwH9dgQ',
#  '5-GjKjU_rYn_SMgMVSmsIw',
#  'CsLsfpHlHrInwBfJmjR-zg',
#  'zDBOdWtl2PsNY38IeoE5cQ',
#  'tXhscxwFTd-ayLTdPx_2yA',
#  'aA0WQpDdksKuDafTGzJf_A',
#  'VTRKrPvUgqAYUgO4HBxLQA',
#  'IEpSkLU6eODCxCrWwSFiWw',
#  'bRA9ZC-bw74iEgx0iJp1bw',
#  'g1cwG-9BWx5HvlrKPIbs9w',
#  '-uybOghOlhc_UHEZvkyShQ',
#  'hkuwpVmoWqmmRNT6ly7eIw',
#  'vPWjHU0ZFjy_9tEtk-8_pg',
#  'RWQDfQbHcjbF8JHrHMlFxA',
#  'kjbUQDXAdUKFXqVgtvLFug',
#  'yFpmlk4flcdeIx7bAorSHA',
#  'Z4rItwH8eQyhqkfGi9_6qg',
#  'eg1PcQVJ6TJMvQPCUkykaA',
#  '_8fmsrxFubASqYw_SAxkgA',
#  'zXQuFIgNgARtX6Nf5hIWIQ',
#  'V2mv5ZaysyAc-L9Z9RH3iw',
#  'CItMwJUX0Dv8wwugxWVUPQ',
#  'JOwThWdv2KZCO_u9MieR1g',
#  'baAxFn7RsH-kDu1Xebo-sQ',
#  'rh2Fyv5A0EBjnWxZC2RRHQ',
#  'KoqcznJYIXg19nzl286xOw',
#  'fxqvyXlml4400BglsxRG_w',
#  'aIFbo8WaP6SCuOFnj_v9kA',
#  'EiSKklI6PPHOoPLHqX1EOw',
#  '7Na1pUcEv3oF_QTRwZ-2iw',
#  '1-gnHNzZNbn8lFwYRF_CtA',
#  'UJEjJgi1xpmLR4b3J8fn2Q',
#  'OPN-dDUBkH7uH-G8nOnskg',
#  'YSE4zpIUVIl0hyHoewyeCw',
#  'O4CBAPwJQ_43KbqArpFxpQ',
#  'MUzkXfPS9JaMgJ907orz0g',
#  'W7Y3cKd50qabs646pZUKag',
#  'eJZsIYlozH-aJ8GMjcZBLA',
#  'LyoBey7pYHult00lhiS02g',
#  'GcWXTgLffuZ5BsuZGcl02Q',
#  '4PE0tDvV9Lo8VW8kDW1SFQ',
#  'fdJde1TCDq0fvH-PbKiiEA',
#  'v9VCObZVWhOPdm1rKt8Dvg',
#  'UpMTSX253d01OPY-3-sjEw',
#  'JITevzyEgskIJc6sgOyEgw',
#  'drui1iMt-TPzJiSkQp5CtA',
#  'lfS2n5r2go3QuaOO7mtYwQ',
#  'SkYIKEIQfEo65_xHNM114w',
#  'hHDltEEGlvuhRjDvfbYpqg',
#  'cJ7EsBomKWzKFLjauxeC_g',
#  'KVbMZV-XJPSH9wXEwuXIaA',
#  '81VIwNUOYQG4zTuSQEdkGw',
#  'oJMwdSEcl59FlX7cwaf0bA',
#  'GsEEM3WYB8rxu_gHcDPMCg',
#  '_XrNNcEbNnut2Q4Py-LfKg',
#  'Bnf-KvDhT8WXrpv2WJEOQQ',
#  'WeiirhJyaAY9kQ1cS5ZhwA',
#  'Zratk2K3CMsgLusfnm7Rnw',
#  'lHK2jZ1sAG_bMl83824CaA',
#  '1zSv6IxBK1LgEWvb4B6Brg',
#  '4BqMMLCAGM5t50HnpdxvHA',
#  'OfITV5ApuW7RpEvpOqJCqQ',
#  'gjhzKWsqCIrpEd9pevbKZw',
#  'YWFbTcVnun8i03XnEU7kVg',
#  'BgZwJBhVWKq1Urs4rKBdiA',
#  'ZNC4L7fkT9ke9Xi9OGL1Dw',
#  'hmwKaQN_f0dnymp7XH2R2w',
#  'rlphr1Hp6_x9e8yRGX42Fg',
#  'aAMbdEgSzj7k5UmGQu9fYg',
#  '-NnBFf5fosrLMeqkEwVLHg',
#  '5q5R-Z54wm45Ec8G8CxZeA',
#  'D6bq08PeNGV_WkZbO572Bg',
#  'ZLFeb8d2jzQsCW21wzOq6g',
#  '21TBXrUyPdyrC57TMA4ZbA',
#  'vc1cikaZWIS2J9JY7IAWFA',
#  'WY2UlNWEHn1Vv2-JpTzEUg',
#  '3FrPTLpqV3dU6AbNS3Y-gQ',
#  'kG_SL19KTLp6Cu9Az5ASOA',
#  'flj6NjfxqwudsBvOTbrhug',
#  'cEHn8OkDjjWQYbMKakACwg',
#  'FVjmJWsjzed0yDGlOB0QqA',
#  'Ve0LUwcrzxL7w0RYgY4Aaw',
#  '7C8xmWdGLipKQ7ZTRs7eYQ',
#  'zpGbH9oVNYXy8YM89qFhPw',
#  '_W4y7ku6Q0uGoiI3ePtkgQ',
#  'LnYL1PLsSOwG3i6M2ecSVg',
#  'skjkxo7Ewz3cbxW4TQNK5g',
#  'AHXUeYTwIy2ZETSpG01krw',
#  'Fio9RpyMAejPEsZhDFdb5w',
#  'qWlFQnkcnsJrb2lhwUF2Ng',
#  'VWgWJiG462Ytm_rWMRxHiA',
#  'Zvs990LXwWqOvjzjsohgtQ',
#  'q9xZ_o95MTmBmLLPnZyBwQ',
#  'qUnVF9NPMsUX4G5nZ5ZSDw',
#  '4O9WNNfnQf6-a5pUt1RIwQ',
#  'm07sy7eLtOjVdZ8oN9JKag',
#  'DSDL_v5dvLOIJ-o5sRhz4w',
#  'BKCyaw3fLry1268fwpQeIw',
#  'p_514Yo8SndKB7dCvGdvWw',
#  'pPvsrGX78-vP6IctzU1-oQ',
#  '3J44PSuAqDNdY3L4WXWZUw',
#  'f-8CECTr5EcC_ppaQ7SFGw',
#  'Q8TGsARjdIfWsnXqgQYHhw',
#  'AXlUeyM2MTfz28CeW6KkvQ',
#  'RI9U93FjT0bKYhz_io0wHQ',
#  '-rleYbGDq6rR1oTJFWG7og',
#  's5o6DQgvrnmJlbw2IDM9zQ',
#  'grFjhD2zEzfjo7Gbp8JvoQ',
#  'Je6-vkrCJxex_cmREVpLBw',
#  'x4f9anzaaBozvJh5nv26SA',
#  'Acapau_RiNy_9M_TieUmwQ',
#  'FrhwWri3vtD7P85xJXw5zA',
#  'Un9kXZRrhnfdhaW33OwLFg',
#  'ci7Q6NvXQ8UZrBHusVX18g',
#  'TaByJybLHGn9QXGE8fBklA',
#  'i5Cm53q0pmklQsX8soi3tw',
#  'Et79VAN692zD2j32PM1E8w',
#  'zGYimABNU5Vk5PKHBtcPMQ',
#  '5kMii2JySygayQpyPBjqCA',
#  'JVHAFY5ijpGyyCtJb6NPcg',
#  'ThQmupHx4KjtijFlDKWsbA',
#  '7LmJ87EijrHcoYRu9WgoHg',
#  'Js4nQlGRjS1Bd5vsAQQfgA',
#  'STO9KprPS0pZVO75VX_bvA',
#  'pJYsQBaibeFgTucnm0rcPA',
#  'rgHK4_IdibIrF990TTRoIQ',
#  'xnpzE2wbif4dZjN0NMhi5g',
#  'HYQoxBC1y1DGPq6pGP09Tw',
#  'wyKi5kzzggDMEQSIGBpjWA',
#  'FdZumOby8Mx4IkdhYVfyRQ',
#  'oUNm5rDUDxu0LMximnNHWQ',
#  'zK-HYsRHsUrbhvWv6pq0Ew',
#  'SZ8qITipYmexfotE5_UaQg',
#  'k5vAqz4dTDeD9zDMweULRQ',
#  'qgrRS9CS8XY-NmoktttIvg',
#  '9vLQrTe8uY6NuHF49YLSfw',
#  'a6myQnEM2qdJMWcYqOQWlg',
#  '8TYNR25ifvwrwYcyKNx1BQ',
#  'NWFqEfs5Z9wUmCeVfTTDAA',
#  'pxyzkPY6a4FVF0aDjBgC8w',
#  'l2sX4ls0PQFWpkDXdXBFdA',
#  'yGPSqnzFfrDKkHpadjPy3g',
#  'S2qfY5qyfZhDxAbFPg4LwA',
#  'c32KGmJRgTpyCTCKZuALZw',
#  '4Pwav7HENZumUr3RJE03ig',
#  'E_9WOCYIGHtT2nbcY4_t4w',
#  'Dr2Uiv9mn6MgUNT9rcoASg',
#  'IzJ36jX6V6ky5BtoN-Agng',
#  'qRBTAUOEWrBY9N1JszH1ow',
#  '4pefQIbqzrkPTlDSM62otA',
#  'gr6czSdo2_AlM-LjV_mvbw',
#  'Tk_FWXueutKii3f9yJFsdw',
#  'eTvp_hYnsrI5-ow_sQ31_g',
#  'h7qNmqTAIc05zNtIpmlDJQ',
#  'EkBaG24NaAyiEkJZLJ7K_A',
#  'FH14lvoIAKhva9KVgvzKJw',
#  'Qb8QNqwCH9VgIsugoHG--g',
#  '0h4oT8ueMk9d6cKzk2t0qQ',
#  'fCMxArYY8wSWxKuM27azrg',
#  'XpVUWxVoNp75aZHusk9T8g',
#  'S4YZloQTAbIkqTNsfAFfnA',
#  'YbpLvFrMPiStbPPkj7K3qg',
#  'ssF0fA9ev2K6JendJaaMrg',
#  'CUmUCdczdg2vZHdlJ3safw',
#  '7PHHxsjyk7I7oM6ENxwZZQ',
#  'YrV3NLnSg35UBIM76w35ww',
#  '1sGYXSkJHPhJ6wQtc-RbZw',
#  '8yStSioe9M9uEoeqlZGY1A',
#  'k6HN0FE8NC8vV1sZuu0O4g',
#  'Qa2NoSc6DphQArihBgY9Gg',
#  'jfWSPWnGjSLHGMz0CNIZtw',
#  'xSI4zpl9EaETOHyzshOIBw',
#  'K3353tGh1hzfg132DwjWjw',
#  'B_T4fv0GlGcZLDpchBX-0g',
#  'LJhQx48XHLggMDxkX4bePw',
#  '9Gdifl4r1t6lHdEu4gzhiA',
#  'O5HnDFz6IzJ3ti3hG65XtA',
#  'R0jNomBTcFysG4I-xMTtbw',
#  'Egxm2aSl_e9PoO-I-0XaLA',
#  'kLm3B6LeboEZWX_4otpILA',
#  'GvvCiaQfD1pb8NU4c20C4g',
#  'ii7v9u3gTo3xvxhcsBu3zg',
#  'U11j0md4DV59nXD6kdb0KA',
#  'c11NnfZEkPQg9khQWjtKWg',
#  '8DP1VoyxKIzoUE7qiVPyhw',
#  'stLKaPPdqc40c_q3dISabg',
#  '9HZ8hY5q2ESYA36uF2lKvQ',
#  'tipQmXdg181T4NvxrXPjFg',
#  'rtl1e2FVr67mPulZFxrkbQ',
#  'O7ly1kO-eDJv9uGuyYgaIw',
#  'in672plSIGcbOj2q5moYwg',
#  '16bmaGpCAqZB0PzjLTADWA',
#  'xzvTed9al7cOEc0S57kb3w',
#  'VatZipEmv3Wx5iQK0QL-pA',
#  'OgYi5x02MBukfxPNFe1ePg',
#  'ZcFrsDhZ6aM45kwHlRkmyw',
#  'MItOIDqGoFZZZJLayliaLg',
#  'az7_up1dApMJhNrOzqUfOQ',
#  '6YysBedbKp3TQ_Py8tmcMQ',
#  'McPU8udr9OLqYKh8wFQpGw',
#  'g-Cdew1rrW2nu6TbgVBjmg',
#  'ox4AXdK4C2ADe5loj66mGg',
#  '9unR5cAeDx1CPtKH2Hctfw',
#  '0fKmCIvKlkXwBZU44D0umg',
#  'J-urqhA-tYOqvwtxjkJfIA',
#  '418J-bXe-ox5Cp_opOWWvg',
#  'ir689oBNmrJXOspb4yq_Jg',
#  'f9M2Q8v_bGqrjbpBO-nrtA',
#  '1z2aJu1qTk_gQa2NRfK1HA',
#  'QPFYr4q90IH4HMoE1XIYMA',
#  '2XKlUjHGk9z-2ckFMcBEHw',
#  'SH-GRUQlUZTco0ofRbwVdQ',
#  'pMltyeuU4SjT6Y8YVy7HBA',
#  'by2k9-QcUwRVIvVOeLU2lg',
#  'fHS0bQ-l5rHME_xXKQSYXQ',
#  'X6Ft4Gh7fQIFyO1MTdrUwg',
#  '_R-0XC3kdGSEmVNH27NZdQ',
#  'EROW4chFZQF1E-eZVpYAAA',
#  'M628_58sbDGaViQrxsPuqA',
#  'XpnMUYT2HDuUB7ycRtw2ew',
#  'X5cUYGLWiauXk3C7h1GMfg',
#  '36LgEtwt6ROhrCtuPjfRmQ',
#  'Ohhrhu1RkqfVciIVx_W5HQ',
#  '3gHpfzI-rUm0viFDDFYZIg',
#  'ebaMzyIDq-6VLn_Z92UgPg',
#  '2YKkLFeOx-0zRcWp0KUv_Q',
#  'jIdpjWPfWKneYPGGtKUM_Q',
#  'g0ML1VMEftkgrtwNUd3TlQ',
#  'VFXKRVzEMbnsDcYFdwiiuA',
#  'tpE7zlJPsfO14024i1d9aw',
#  'RODUc87UULC1p67gAeR1xw',
#  'VRw00O-WCrVHaGTk1Jk6Cg',
#  'XgodmqFjRvbCG3nfLOKFvg',
#  'dPdpfqKL2y6Id8RtqPqdkA',
#  '0MP38Eo_X45oHNvcKTLkRA',
#  'FoO5vOMb3_nKGmMiDUm8lA',
#  'y5qEpAfJQaOjjG8ZJWrp6w',
#  'pYoKc9NfstkvwR1ZBAuGPw',
#  'o_1beq3LiW_JH_rgUNBoFA',
#  'AsUvXYx9ZVn3IMJmAIwhYw',
#  '-tnodf38uCXjogMhZtcWxw',
#  '1jFPCW9Oy1D0gWudY7w7Ug',
#  'ki7OU-sg_ci0T11l-cANhQ',
#  'CQUDh80m48xnzUkx-X5NAw',
#  'OoFKiEKyw97IWhbecLHSwQ',
#  'zlXlvI_IKONWpzOXugfwbA',
#  'yCyYKXclouR94TnpRLBGRQ',
#  'xwm5nymG7-CraHZsX130tA',
#  'M9puGD3VU5FuhE60HklCvg',
#  'OHbUGOs8hJS95foAhD7xUQ',
#  'mZHk_DPbeUTQBZOBOyoqlA',
#  '4VbB9qS2Xvk-bjAI1bNlGw',
#  'K2VZMLykxnctDXWgO23lJg',
#  'iRPGY02VkT5qW3iszBl_yg',
#  '8P6SjKjlQkNfwYSnBVu6Aw',
#  'ku7MXSmR4uStJZtzh6ALqw',
#  'x6erNzhuM_c7xW6PlqClIQ',
#  '63z_FCCfTar6Q6nFCNRezQ',
#  'XcwBT1a_5ZjdaPZTZOhN-Q',
#  'GYklwfO3N5BXeZ1RjHPDJA',
#  'U8BAWPaPPe9sUp7m0k2fdg',
#  'b3k-4r8F0o1n4TxxmuN62A',
#  'itm7J1IWFo3YGBwcZUin9g',
#  'TCauYZf5swof7iCPsBUmsg',
#  'fw9gey--wpQ9syqC8GleSw',
#  '6UhVJ1QlO1Y-BVMvRyuljg',
#  'DVkshdrhQUL-4ds0gJQQKA',
#  'HM8mOekJ028ck9yfTpldPw',
#  'lf1m4CbheuUR7fFZoLGRvA',
#  'IGuCHgHr_K0XOVlEzKcIrQ',
#  'CvZGAp4Q2QgJbYqLG1Fetw',
#  'ijfxzX1up5MHHt-BdGrrYA',
#  'zxxtMBaLWnhFc6ZBDDsCtg',
#  '86EB3KT3H-Eyc7sl_WsUkQ',
#  'waY4AzngWdZ9JqYBrUUmew',
#  'T6TjDj9BQuS46xDB8eeHFQ',
#  'YYGZyYuGkAo5rLKinakdig',
#  'X2Lx9YYpwH1Ozb4VJ-OD7g',
#  '7lKzYA3pZWxpnTFRNpPCFA',
#  'GG0mFsEXb-02_dzFPqRV1Q',
#  'nPJw7YpKgHE6fowxgl3l1A',
#  't4aq9buiAuyciHxr7RvzNg',
#  'y9WhhW724xLQ4p_lGQCQkA',
#  'TN4W0bPo7-8Pi5KUVAy8aw',
#  'uMn7wkivl82sjv0-H6wlpw',
#  '8nCJfTcDv2qDW0HkGQpOPQ',
#  'H4Q_w39G5uBIkHUseMKhpg',
#  'YUFqbfAePA8tgT2zE2y4xQ',
#  'm1LzN8vRCuJYwrDfJA0fiw',
#  'q31f3uFJsFTNFFolAQkWCQ',
#  '2botYYVjkOyNXYhzYZUrIQ',
#  'k_muz40jJaiY1PVga6NDXA',
#  '5BpJEC8YVi80ecWT5CtlfQ',
#  '8UPTxp6SXvQe6JoEbEGcyA',
#  'FqYYd3p-phMkZ5GVjkUzxg',
#  'reGfsd5pE4W85VSS6NYhOQ',
#  'tGxC-bdojFzROxk9oepRgQ',
#  'mJWhCoWXpoxgAHXWd0c-3w',
#  '3WSgEXBS9SQkLg37rF9G3g',
#  '2M01rniHjqap5IBVQ_eV8Q',
#  'HPhgvrUlHVmOEuOIGLEZvg',
#  '651eEf0zlIh9k8Kxqzzg8w',
#  'HM_4PEkC_NCaS3TOas-sAw',
#  'PNTbcuPX5V81XibwrNzskg',
#  'eUBGDZ2VEglZEFEiZiNTsg',
#  'A5696UJqaQMQVtWStQyX9g',
#  'wKLYI27-HlYoI_KpyaLJjw',
#  '9xULVStLCR4ZmQ_YaU6m2g',
#  'zHvS1F_6wOPSLUk6vpDEGA',
#  '7eeANPaL34dTeUyqy9cIYw',
#  'HFPC7kUjgRtuBQdc_1X0cQ',
#  'IPKtxPKLM-PuLHGoT1e7iw',
#  'xl2zFMHnMfHBXe1TNR6i4g',
#  'eAA9CmVmPIRewS7l6l7xbw',
#  '45Za0-djDjG3nk4zSlGfuA',
#  'pRfWy61wU9e1nrCVrOEWLA',
#  'L8PRZYJ-Xpux56ChOAqgZA',
#  'zkamNMEjihh3zN7lC7_WVw',
#  'WWnhqRnWWjutMqh-2SzEuQ',
#  'Sf8yKmUnsTk2HNzLpSxzTA',
#  'NG2mzp-BFKPsgxy5ofaQUw',
#  'vsikhxSLtMk5APIf9U7C0w',
#  'LfleZY423IgY6tHULVXGcw',
#  'ojxS1v-8nUvEEx4DlsPQrA',
#  '0QdwQLVxZpgy9Qb2Qakflw',
#  '0MeivhX0kZCfV3zMtHtk9Q',
#  'eh03Ytv4exbW33L2erx1kA',
#  'Mpk9Ez93CGqyknA8Qwd9kg',
#  'OSzSzIxLnTQ1tsAwoDoQqg',
#  '9q-Ss2Mck927jSXk-8vF3A',
#  '5exOQK8FRpAfw5S8s2a6gA',
#  'H_BTSU_avg948rHcxwa9Ow',
#  '2OLohmwFrl8ru4w1mUXtyw',
#  'pTUlF0nvcUOEbg8E_8QWxg',
#  'SBpz4xJ8MnrzXOpWiETCyw',
#  'RFTVBFlgM0cqvl1daywfjQ',
#  'ztVQFPr9khc_TjsBny-3rA',
#  '6T5zXLWfplNlvZ8E3bKjgQ',
#  'd1LU2oIXZ3QaU5fZ3Jp2HQ',
#  '8diIRer3uONzEKAQzUbQMw',
#  'xyad5PXaHTdKrdNClXbMqQ',
#  'Z6yq2cCc27QmssIFKWMdAA',
#  'hysY3Fv38CAoY0q7e-5mUg',
#  'zZyvrfNSWk7rYV8Zy3VLvQ',
#  '5pOgHm_SvqM_Yp5WEmNuFA',
#  'ZehOtBTToGUA1UWFxA6wSg',
#  'pxHOGxXHhUYY_mgS4ofI4g',
#  'HFECrzYDpgbS5EmTBtj2zQ',
#  'US4XWHCxjPA07Q_MESq0cQ',
#  'pjphaZoEhLqBvsC3y7xMDw',
#  'YOw1yg8THktCCioY2q55_A',
#  'X5gSx0VieHb_TvwX23y_Jw',
#  'ZOMeGiZqtuXJIKlEDuYloQ',
#  'aN3hqwdyeT6AmyUq3GgIIA',
#  '2z4CSJ9EH0L-5BmzquYnSg',
#  'Q0HgKp_xW2lb55BpfSCz7Q',
#  'coKnuxLznH0FHb34m4ZLCw',
#  'NNyr4wknApjc5nF9QOO2Mg',
#  'fj654yv6kkCtQfygTSWQYA',
#  'cwChkLd3jcvmqrk5UfUGJw',
#  '9E0u_Wsf4N3rTzG591pTAQ',
#  'i_Hm2nOQuIZ3SRiM5gcmXw',
#  'meSxukeC8mECIZTPzVxIIA',
#  'RmXIjppHNtVveguN10iO1g',
#  'yLTonzc-sGZvfRwUsx07Xg',
#  'dkkMQorZE0EF-F5wOiqA7w',
#  'KtUS6HMhgIPHXuwwkwReEw',
#  'JprmPc4cZ_TrydXRhWo2gg',
#  '7jmAHDHVFTfoJ6v1XL8eHA',
#  'SRrzKuUb2619fVa8huw2QA',
#  'rVxwIq-GU98GC2xMulsSqw',
#  'duymKKwUruH8GwbvcaFd0w',
#  'Zuwoq9rt5kbO48B59QJiRw',
#  'vGVQSLDRlnfzHoJpJgSsFw',
#  'mmgLHTFOvWo3NjDXwuB7bw',
#  'LPvaDDpoeVw6DB7Oepd9cg',
#  '5AysWo91Mw7_bvBtWUNlMw',
#  'jZO9ZG_9mf34bEzpZCZKsg',
#  'bcB_Sq-0NkU6wWgV_b66TA',
#  'C4-2FfgdO8IrfJX9G40IPQ',
#  'zFszUTKwfFIWK6EAYCyR7Q',
#  'v7gsMsxQrQlQ4-JCefu4gg',
#  'FVbtQgcCmWmQ-D6IR5BfZg',
#  'Zr4N9sG31fybEa-l3a_46Q',
#  'yhgx2AKeizmRcFVPr_GIfQ',
#  'oXGauhEuZJ9-fNlZO02Pyg',
#  'UKSw9kfoBfdatSMUl-jGnA',
#  'gvB-AVjjN84YwLxTIV-3hQ',
#  'nPBzbwWR6ioHRONgsfsTTQ',
#  'pgxbiGCqgNV878Sd_v7XBw',
#  'KNkoLCrAUJ56wXJnzhNtiA',
#  'HQxWPs0oBHwGaKqsw_dxiw',
#  'FrJ2PWKDM6S0S9yyid972w',
#  '57tf_RmT5o3BiFj2gpV-Jg',
#  'FP4BR-Aa9GrkoMoWguoXyA',
#  'F6hz6UdboHgJ8DLUGCFXvg',
#  '-VuSUcCZCbQcdSdF7w9USg',
#  '1p4wP0QzgdWXWYnRSR7MBw',
#  'PBA1rCTmVaI5APfQ1WgbyQ',
#  'wV7AObFcbp0qfouPfxc58Q',
#  'QmYOI_SAzelAxRTgOcYLyQ',
#  'q9Tyln685OEpIWFUdTxoYg',
#  '3wq5u6jaZOYzkU2kQOqRwA',
#  'uQOMhO2-70PXChcIq-fN3w',
#  'qwvxMDOxj0k2sfydwaruog',
#  'dplrPaQpUP8n-uxPE6eHZA',
#  '9Uh2NaNHX14KKi85uv9AMQ',
#  'H6wh96nudB8jrwrQtLPZ5w',
#  'FlXBpK_YZxLo27jcMdII1w',
#  'TvsPmBJt_Ei1RdOtVhjjiQ',
#  '_tpzswb4NTS4bniz9aM1nQ',
#  'xQXUG94oRQxYUHZwS6Cwzg',
#  'aqWXHhcR_CdmKmxggFOlEA',
#  'p3heVCnq3M0H2LMxIuuc5g',
#  'IxOblhSSL_9vEUf3arVbnA',
#  'OWnYWg8L67W-moQJkjrXPQ',
#  '7YuX2pNvwfdArAizyLv0oA',
#  '15znE0NM6nDU2oR-i5RXVA',
#  'vTWyb3WgKHZk4EnLsZfrBg',
#  'So46aZ3y7zRl2VmFK35vCQ',
#  '2-sRIfKT31GFQD0OCnOmwQ',
#  'rDORGCGHV984OBXwqu2FYQ',
#  'z3yOJaNdvqzXc6L1RbTl_w',
#  'vl29cxjaJ8Y_Th8F0R8OyQ',
#  'XnWTpZeb0atyolIc5-XRUw',
#  'n3yEb3IYT6Fab9nf7luifg',
#  '7mzo8uYToyTkdl4kpAsgiQ',
#  'uUcNCwf86aea7F9AGFBJNQ',
#  'tAStD3oAe_ob9Za2H7DQ4A',
#  'ftO6S_Jg_eqXhxa6qGKP8w',
#  'lT0jFHCIloX3bnF5eu0ERg',
#  'EVaW-GGDEbYrYhgGUmO0DQ',
#  'dI8kmo3hMqY7xwV9TmJlqA',
#  'TBq1yn10ZcLsJzQwgaTBUQ',
#  '9X63Z6GZfr3rfZImi8rNiw',
#  '3hANLGwpP5tXgHOes2XheA',
#  'clLKvGH-1oauaInqjp3jkw',
#  'JXbz8URET4T6SWVrDmKWTA',
#  'GmQR50bIII7gDNRYEgfXfA',
#  '5dZTVQxo4szVKkejgkCQVA',
#  'rcU7ysY41qGppbw4pQgjqg',
#  'gf4tyQgQOtVMkOdvveRHVA',
#  '-AJV31rH5tZmKI0f0rlQnA',
#  'hOnMliHBDtUZ4qyIE-HJ7Q',
#  'yU9VHS_AuXUKbdrzcoDTNg',
#  'l1ExDt-skQ7ebpUGZZKgyQ',
#  'BUwajB8j__9-fA8405vYNg',
#  'tLe5dddFbwDb7IUCUUC2Gg',
#  'rlDDkE6G-nMO-z0hNqekzA',
#  'XsL5Dz2FXpoGjIwX30hYfA',
#  'aZixAQG6m-dyGtJqm4Aphw',
#  'm5Ou-7SxevQT0XyrCiJGHw',
#  'k-vckI6UzvLVZmd_W7WrsA',
#  'Wttx9bqHkOnRXokSrAjY_w',
#  'h6RctdQAXQu8drV28iv29g',
#  'DurbS6wtH3iHkL-X-XUOEg',
#  'SNMkSpTy6buAfhKx6NSNJQ',
#  'FhydOYT0JYsk0iTcwzggpw',
#  'NzXvqHFS6YYDY_qnfCHc7A',
#  'GdNx0Urm3NInlWnHvGHJ6A',
#  'o4tYl3Hz0oDfpNn4k02DCw',
#  'dTiuUeT2c7-JcA_ta3TC7g',
#  '76ew8CgYNfC6NY2deluWsA',
#  'XPxM2kMdP-RlkS9TseJHbA',
#  'EiwxlbR8fb68lMgEXhcWKA',
#  'fFvCQoOEb4IW-FqpTO2Z-A',
#  'e9x70wHE9-3FBqm60n4uHQ',
#  'UYUWmXsUynm4sTkwk9siZw',
#  'T43D20OvAS0fJ1IgQed59g',
#  'uGZ_B4azzKRFGEOGEMkM9A',
#  'kepqZPSeGh0Ns1zfOgL-zg',
#  'DihTsliUxbqpoA9W3uRDBA',
#  'GZ_000Yr72OFcKv9ZaBseA',
#  'KmUFaI21IQfQWajv3BrEgw',
#  '398uzpPdN0Uu9ZhePPfebw',
#  '8gYDk0qh586uzePzzU763g',
#  'Sg_BvnTHsbc1AABiJjaiPA',
#  'lngQbdPu3BJa8bmNmxexnA',
#  '0iq45WV_h_j8SXjR4ytcJg',
#  'EWzlzkAYBh4ZYujdy2j-DQ',
#  'd4lK2R2WpmoVmR4poZ6hXQ',
#  'GiadmcSjmhHrxVQz9Y8c0w',
#  '-a-Czzeam1izGg2SSUN87A',
#  '3GiMheHTAzo85rBm0W_Yww',
#  '7WssA6jbxkr1Yk6slHOyDw',
#  'EQSHAfMrLKqYK0zLx_01yw',
#  'vM14ysC_qD69WI0HwoBMuA',
#  'G3j5x7srU2Wnk8BeaEf-tA',
#  'TaibKwCzl77Lu3-n7bofMQ',
#  'rUogQgFEhid8om3oDomeKg',
#  '49JhAJh8vSQ-vM4Aourl0g',
#  'Z0xqgGaxDrRd-0HsVIvdAQ',
#  'Wia9sTPJnFWupi3v6hJevQ',
#  's76J8AsfaaRrker3s22ulw',
#  '_KeuaQCbJsZ7cipYpBPxDQ',
#  'iWaAqYnqVMOpurshXsCa_A',
#  'JiUmz7l4rNz4-YmOj13i9g',
#  'DfSHS8qYCYYtkCV3_p-tjQ',
#  'L4Rlr_iHSW_wnemqmksmKw',
#  'APqDwmVqnRF0jJRx4YBRxw',
#  'NbwxzbxcTzx9KjOroh37VA',
#  'NSkU6rZ_pNu5JQppodY7tA',
#  'uJxSIkteqnGbe1SnbWQkYg',
#  'kF2sEC2B1nJlxVFr_jaEQA',
#  '3tLPT5PzOemSed-ERxwSQg',
#  'K5UmrBmAqS-nIT2Pm44itg',
#  'Rh-bm1j5USQTOPTgZHqjtw',
#  'GjwfZjXk7A_bteA6-FxxwQ',
#  'Nv7jyW-Xag9-1uAXZZHUfQ',
#  'FeWKX0KT1xvOHc77XqDTNg',
#  'PC-jDSOzMz8gN5RkayJBEA',
#  'C6LV0p8L6IfBfh1YFRkWzQ',
#  'tmQ2UJLn6ktTy5XHRJjivw',
#  'E7dNhALfxoE5OcH0ybH0Sw',
#  'cMoQqT_j_FD1gO6EEZzOIg',
#  '6-YEfYffIq30kyCWQpFoow',
#  'KD1cLBiElr-agbHlgEh-3A',
#  '8tj9792w3U7lv_XkErMn4A',
#  'fdRGp5Mp2Cbl5JTei-Mibg',
#  'PWcDbTaoBcBtumbkS5gUJw',
#  'ZIOCmdFaMIF56FR-nWr_2A',
#  '6snhyTl6iU8ti-1EIJuFvQ',
#  'FJ6PUyukzZxl6SMErW6Jww',
#  'hfu64kgzsAPCsN-AEkRB0w',
#  'GaTWkVy-pY6phZOqW6ykuw',
#  'qL6WPrAtufm7ae-B6Cu4Hw',
#  '0xjL8_225GIpec9cE4yjWg',
#  '1e0y0vUJiEU2l2U5Zw7YmA',
#  'wPGr4U0rKgKH8XNSSfWrFQ',
#  'zIfzrljT0hEyrndvxXVdFQ',
#  'bo_ZzmqxtIJpGWxXgvEPiQ',
#  'g64lOV39xSLRZO0aQQ6DeQ',
#  'jnaC43lMyL1y4V2RsA-p1g',
#  'abFAKQT1mY4y8yLZ15EWJg',
#  'qX-ndFKeVen4Z0FQfbHKNw',
#  'y3IH1jtMxGkSvZYnCnh5Yg',
#  'pxBmvgpiDMN161PwHDtsLw',
#  'SdlozylmEKkBW910mGw1dQ',
#  'rKF8XOPwTU95DHABj7kHaw',
#  'cLpT9ZCzgr7H6BWqDRs2Og',
#  'k9G2fOhsofiBmLtZrRIeGw',
#  'VoGgWLjco5FxRg6gwskCBA',
#  '-PfB5lPsUgrulIGQ_u6JWQ',
#  'q-gpZeBLnhCBATuQzT6ANA',
#  'Hjfbo7zwpCI5CI5OjkGMqw',
#  'FbDqt_QhPnWv4FsU9hkkvg',
#  'Ywbgl7YbSQHKOx4nZ98HLQ',
#  '2tiS7fqBIwXMTHJe2GHUrg',
#  'c45FDBYGyVY-dOrvbs45PA',
#  'p2WzI1eXcleCPUbbwJIBUg',
#  'LBV8oWri3DhnlzY7fFqUFA',
#  'afEBLpcr3rZNVdYnQGf46A',
#  'AgJxCwwC90WwUOv7g3tiXQ',
#  '4LO6X_jyG5BCo4AD_rtKAA',
#  'gvyYZgFdBbcT3xGjWOvZag',
#  'p4FsOflitbyFKseYi1610Q',
#  'IyIsFkVY48JWa01inv-7zA',
#  'Zl6uyhgGrbqvNjfkhQMeGQ',
#  'UZ6YOaTiZ1lTZWKASIkVuA',
#  'syvwUKQJ4OYfmL_ixVLMeQ',
#  'tAHMuChEo1Fs6qaRJ7pPng',
#  'OF1Dwu3fWeyNzX2ehlyM3A',
#  'wMEQoS2W1t8Q0qwWJ1hqhg',
#  '9n89LJACQq-V7VtG_GRsnA',
#  '9E6ghRHPfAOmCJoR3s_pRQ',
#  'a9qfIqE5toA0WgOYTMyw3g',
#  'afPIUwUh0C_lgHvt77cneg',
#  'YdoiyM2IeN4ymZOKA156HA',
#  '2H81nkiffTpo2ec9BNeerA',
#  'jpKRgEf4ulYIQJ1Ls_PcXA',
#  'AiwVzxg4paqeDX82O4oFLg',
#  'FyiYuZrIzSkgshdazHZCWw',
#  'jsqlHAhEEKslf9etajuXdA',
#  'SlB83-elY01FcSCfzJC1Hg',
#  'a21yEFhTXEJImb9hGl0JyQ',
#  'xOlQ8ZLzlhnMYtfda9zUKg',
#  'tlY0QMQDyfjQAEwHnzvFnw',
#  '3h352DEsa-HgjkN2FJsSiA',
#  'nmqX1cxPOYHwql5e4U9LuA',
#  'uaiBkiGlMpiPnn26kM6sHA',
#  'pYjKD081FYDHrEpukuHHyg',
#  'PWEMQK9a9ijJc9sndnJUzQ',
#  '0JO3qopqVuydpUgLBJl8Tg',
#  'q-0qnT8ommeAyJb2Tv7AJA',
#  'uQxkH1qQe_pF5XDLJI3XdQ',
#  'BrFSDMl2V85mW9UtbAeUAg',
#  '0JeXUOkZrtyyMJ5nEjCsFw',
#  'VBE9fERUHQ2Lh2MgpEzfIg',
#  'GURfFLpdIsJiIrtPPs8MDw',
#  'QldTZz8E1mTzFBmmcjrLBw',
#  'GIMg5oHqsJXdRq_7tR2jjQ',
#  '1Aode8tVfOQzBd5bgKT7SQ',
#  'IDVFG1pNSHIHoVuoLuZpcQ',
#  'zieFgZfbaA_6-5v06nOQZg',
#  'DTWtZJAIPMrZJwUJV0DJmQ',
#  'm-CzLdA3lsF68MqG3ZKM5Q',
#  'o-UlLW2RiO8y8uWVwlG3Sw',
#  'tGgTIueZy1JNTzQD9rkZLQ',
#  'Qsv6jcM2b2-9u62jWKboUA',
#  'uQEqsxqT3U6Ll1dsnqst-w',
#  'LMpEiyPvwo3AnIONClAeJg',
#  'HwMZ0ld2P4V4-kSw-YxjGA',
#  'TR6x7n94q09D3lz2amaGMw',
#  'u1cvQWB0lB4YsIbtSlUR7g',
#  'zdw1jwmw1TNLZgu_is_Seg',
#  'NVndhVfffw7ScRKviRdRYw',
#  'ij4gu0gw-9rDmRKahnuz_Q',
#  '9uTysypqImdsxJDlBXz_Ag',
#  'sVr6_v-lwixu3VREOO9XpA',
#  'yE5k9M1PIYMyGljYF10R_w',
#  'VePQan21Rmiw_xNo_kzsAg',
#  'gVFxZMcuG_Tal2_TnpmUPg',
#  '2pzrdZiY66lRAlqgnPFtRA',
#  'Q97QCDBnJWDiFUhg8uJcjQ',
#  'IOhVIAjtdGo3NZ75_fF4Qw',
#  'OLdNS8aBPVHm0E95M7VV-w',
#  'LAwptwS7nJwPkV5Niy9jkg',
#  'cEDMie5DjE_00sJ23H2q9Q',
#  'KxrTQnzr83z0HZnrAkkeGQ',
#  'qg3dkjWE7TWGnCQuyFPhtA',
#  'fR6bUB3KSE_1QqTMo-2oNQ',
#  'Xj4NPAq2efs4mzS4kFHGyQ',
#  'ckcA7pXD1BMjIzHVNrD4xQ',
#  'WL_U3MBUfTkeHL9lYxoleg',
#  'q8y3scPhJlcvCs65i9w-zQ',
#  'loUeqD-Ojj2S46UUfuyJfQ',
#  'kKgIaWBjKOyu74t7DEQmJA',
#  'cDSOe0MuZr8c4ctrS6PM9g',
#  'X1xcXsNOKnniwo_XJXBk0Q',
#  '2nE0zU6y_F7gkwHi3yL6cQ',
#  'nBdv5Br4G8pDWXXqSXhUug',
#  'LWGcVexruRJXPIdZ0eLnfw',
#  'Gag5ANLthXs587HOpWElIg',
#  '771OWzbzelsEeSlx8QsfsQ',
#  'hUonmkERd7l8DTeSXawfOQ',
#  'uV4edOcsZ1MuCmOUSM41Xg',
#  'GtAvwG3oTH4RxlpiDbO0tw',
#  'LNz5NSoV8XVZhxIp5wYh3Q',
#  'F_NG8ZaNVriV_hujoOejIA',
#  'BLJV3zzdAmGhEVBkflhzOw',
#  'fmbP4BZBaOkMtfG1gWg20g',
#  '1Jx-KL8LGqNpb7z0gDjGaA',
#  '7GzQvccSTf_e7qEyBj50kg',
#  'hqSXx-zbBvnWW7akjPhZNg',
#  'y_uBHMh14ZrZ_gvQxxE1Gw',
#  '9VJa4yxtnLct0pN_1RcD_w',
#  'xIi1whPhlngewfOSTv_PMQ',
#  'bUDaly3i9QA8ItJYzboirQ',
#  'UwdoumbX2bCuzbfL4AyWHg',
#  'HnpouZXIQHeqezf5gWchhQ',
#  'g0_x4kVvJAYuk96oCcbOmw',
#  'R7KJolr6cHwF7iRJQs98bw',
#  'f4dLioOMUxpLq9a1ph0REw',
#  'UxgoEIGhqsKDXuSx2P10_Q',
#  'sx2LC2530Q0ZEUQ762h9vg',
#  'T-EyBBZlGsJD3n7Uc_9VOw',
#  '6-VdlCal_FtjGZG9RXdCOQ',
#  '1hwTDYX9S0yyC6qdkfTmLA',
#  '0T2Rx9W4KMDpIie1CqRWTg',
#  '4FeyRoIT4ihyjJFLHdTcmw',
#  'S7Go9U1I_OB_HGZzKNMJ3A',
#  'LlgZ54wIgIXcgBtAbysaDw',
#  '7gbbdcrC9dUj87yH2UE7Gw',
#  'u5fnrkB6fiQkHUo27rJMrw',
#  '6Mv-qMJyxSokCu8YFM1o0A',
#  'xTGpw0x5EUj11YFhwr6m2A',
#  'rrRZ2TubdRzkAksCwzHtvA',
#  'PLCijWEcAk74aiYxHb_tYA',
#  'oH9K7eCuNsYr6MmlM2ZjUg',
#  'FkiRQdPqgjj27wKBzf9MDA',
#  'Dcu466-o8oVYQYv_xUM_7Q',
#  '_UR7Oz7FkCiTEKG8F-GvXw',
#  'WMLorEskmIAKMt8lB_1-oA',
#  '1-icjsOsrv-zxIvWr2VW0g',
#  'qIW7sRXp_SauZ3p2CxF3tQ',
#  'vScaSrM91Z43ypSR9VfKGg',
#  'mFnQAiZGE0fsLfLKpzKQzA',
#  'EnZb0blM78cUkBLfeivJaQ',
#  'S0xQEAwvL2_XCdS06xEmQA',
#  'g5qD10shooDJEPjt6miMrw',
#  'oO6VCmISYMtSbuKZpS2UmA',
#  'DAvrtfdKcTrROSNnCD6fYw',
#  'PntWHBXMz37_GHPtjY0_2g',
#  '46sZk9ZFAIu_bmJWXEOJvA',
#  'QRLfoEYRAQyzY2DMnmnCiw',
#  '4CbwHg39p4eLpCe3HfGZcQ',
#  'ZaudfTiuSeTX2RiILlfN5g',
#  'fcG6PdOWJv5jr3_2-jxC2g',
#  'tlxpbxBH8tNdM5bUmt4iww',
#  'tWrBHzZxCytJyJvoFG1uGA',
#  '0tqhavI8azsD617E-ye-dQ',
#  'bcHgPhn8sgmgMR-IkmL0Jw',
#  'b76FcjQd1RkpnP6I-ajhjw',
#  'QiKaFDRKpMBosMF1fxLPZg',
#  '6rifWcJIpSDzg1llvpna2A',
#  '22TWnCM8otB2JldL5pXeWw',
#  'mpDMGJi3TtxZIWWEsbZfyQ',
#  'Ks4NWUzT6XUwEhwJAPCXkQ',
#  'Vj6waVhIVS-G1LmQphQpww',
#  'CHeMEder5ijEoCPLWjto_Q',
#  '00njy47jpw8fW40DOcrEew',
#  'zkpu7YEsjef0NTrUq0aS6A',
#  'SssXdhbeYJOCF6sfSFwC-Q',
#  'dheeM9UTMy9HyBWHh1ePQA',
#  'DHktJ_qApuCwKe_nGR2x4Q',
#  '_BcWyKQL16ndpBdggh2kNA',
#  'GcEaEhVBp0DcAbgdPw41eg',
#  'IkFjRnnI5trMcwHHl_1Vrg',
#  'UiLS2rvjNeoZE9TgT35UtQ',
#  'lExyz31t8t6DBRxmu858eg',
#  'CttEj5z4XaxPD4-moJtcgw',
#  'ZzbtEALaj_Goxx2uV0OMiQ',
#  't1yeyK0oF2KSLKgnGrnqDA',
#  'hDsxdlsFEDETR-c1YwYHsg',
#  'YOChRzTztTL_KooP9wEtSQ',
#  'YJh8n0Wm4bJvP1mDyWo0Qw',
#  'j1JLPKieLDpFznz1AzbHpA',
#  'nudeZ4nKoq49qpFRWCXXDA',
#  '_ytx-JT-RZcTA4aovdmR_Q',
#  'LT8St8zfRqI-XUKtjZFfxA',
#  'kNARmp_ZMdeh5In-N1dzng',
#  '52qcVq_QiqVW1ydwujeBwg',
#  'f5KxH3YahdmVBgS1axPoWg',
#  'ynQbzhxqVhDXK2akhPggww',
#  '-NbeVN5tnwdyYAvdNkKMjw',
#  '-LFiSp6BUfV1LfygUZWs0w',
#  'xI11p4t2Co7RwWuBc82lPg',
#  'cbkk25sZbZZm_YFNZA-x2w',
#  'dgsCon0Z7fjp4zYe4azBww',
#  '2Gy7OX3zFVfNeeHLhmpzJw',
#  'P7kw2Cw8Z45kbrVjYAHr3w',
#  'Z8Q6AZm63tM3eLz8vmdk9w',
#  'VH7nJ2DdP5onNpSUWy0lRw',
#  'eBHiHna-iK17onn08al8wA',
#  'Ayxa14skw7ogJy6Vv8ecjA',
#  'ARXswZQ4aDfhPnMYSbzcSw',
#  'oDgFJv85M22F26LESCxAWA',
#  'SsgDGJWBNvefjY0z8XsVCQ',
#  'vn8nPLA7J_GkHEiW5vEmbA',
#  'y_PMpgAxTWUIYAmzfFc6VA',
#  's541oLa9Xx3Q-f2CO6fNCA',
#  'P6BJWFBDrIfb0A2b3JqeTw',
#  '4MHFQcFfHzVe4ISx3lvHlw',
#  '71jyMsiBN-Qy9fo9o9Nw3A',
#  '2ZZNOoMQ7WFvFoxDUFw1wg',
#  'fO14jew9W9icFLuwv28sVg',
#  '-d_Ctw_ilqYIaWhKY3Dlaw',
#  '0jcvdm56uvqE6OIqECegrQ',
#  'iePCiaqrMz79hMy9RVj_WQ',
#  'mxnis1VG5Y3_h-fNKjtX-g',
#  'cUk4n3GMShdIr5pLyt9PFQ',
#  'w-w-k-QXosIKQ8HQVwU6IQ',
#  '8YKqSg5lLPJ1Su2Tidt7gA',
#  'j4cmflYbwAktOxZ_iiJCOQ',
#  'HZRfI9weev2Vr_w0jPF8-Q',
#  'ZuFdMRa9PqJ9ZE7MpueXKg',
#  'NojIZ1w3kdXlmpqseBIGzA',
#  '1AgxNI8CUttTfXYuO0tO_A',
#  'mXiw0HwmtY7eL8hlnVs6aA',
#  'WDrVbBxsNZt-0ytEyUAaBg',
#  '2oPvG6BQrfNFqIjy_sZj0g',
#  'UTr4PU6YlsaywlAR1afdlg',
#  'pQjNCZ3-QZXPtgVeXcKCXQ',
#  'W-5VHawa-mOe9fbnAeTK4A',
#  'BogJZF698LCfc6Ff2EimMw',
#  'PgzrB25x5JBtiDsMYtLmUA',
#  '1AXZge9JRr3x-DWE6Fg_kQ',
#  'L6wmUBC7jYhaMLUKFf_5Ag',
#  'HDiU7ZlOUaNOoflQb1sEtA',
#  'XVFxHMIRLWiUiHu2I8Zelw',
#  '141jd-Tt6--RIr9OcJOu5g',
#  'soj3EaoFAhGqWgzGlfTTtg',
#  'LZZlD-7A1o_lCQZAt_NvLA',
#  'CiYRhDyFbsDbWR45uv822w',
#  '90QrD73MiLPjs4mtkmBqQQ',
#  '4tK3tiB3zggiYudjU9H03g',
#  'WyvvWRCCHizctkFdGWz72A',
#  'NpdXQqJFmuQ4wAO9CsgzUg',
#  ...]

# %%
def get_category(user_query: str):
    results = calculate_similarity(user_query, categories)
    return results[0][0]

# %%
def preprocessing(input_data: pd.DataFrame):
    encoder = OrdinalEncoder()
    input_data['name'] = encoder.fit_transform(input_data['name'].values.reshape(-1, 1))
    input_data['address'] = encoder.fit_transform(input_data['address'].values.reshape(-1, 1))
    input_data['city'] = encoder.fit_transform(input_data['city'].values.reshape(-1, 1))
    input_data['state'] = encoder.fit_transform(input_data['state'].values.reshape(-1, 1))
    input_data['postal_code'] = encoder.fit_transform(input_data['postal_code'].values.reshape(-1, 1))
    input_data['latitude'] = encoder.fit_transform(input_data['latitude'].values.reshape(-1, 1))
    input_data['longitude'] = encoder.fit_transform(input_data['longitude'].values.reshape(-1, 1))
    if len(input_data['attributes'].values.tolist()) != 0:
        attributes = [[val] for val in [', '.join([key for key in review if review[key] == 'True']) if review is not None else '' for review in input_data['attributes']]]
        input_data['attributes'] = encoder.fit_transform(attributes)
    input_data['categories'] = encoder.fit_transform(input_data['categories'].values.reshape(-1, 1))
    
    return input_data

# %%
def query(user_id: str, user_query: str):
    assert user_id in user_ids

    user_reviews = review_data.loc[(review_data['user_id'] == user_id) & (review_data['business_id'].isin(business_data['business_id'].values.tolist()))]\
        .drop_duplicates(subset='business_id').sort_values(by='business_id').reset_index()
    if len(user_reviews.values.tolist()) < 5:
        print('Insufficient review count for prediction')
        return
    reviewed_businesses = business_data[business_data['business_id'].isin(user_reviews['business_id'].values.tolist())]\
        .drop_duplicates(subset='business_id').sort_values(by='business_id').reset_index()
    assert len(reviewed_businesses.values.tolist()) == len(user_reviews.values.tolist())
    
    output_data = user_reviews['stars']
    input_data = reviewed_businesses.drop(['business_id', 'hours'], axis=1).drop('index', axis=1)
    input_data = preprocessing(input_data)
    model = KNeighborsClassifier()
    model.fit(input_data.values, output_data.values)
    
    category = get_category(user_query)
    print("Category: " + category)
    businesses = business_data[business_data['categories'].str.contains(category, na=False)].drop(['business_id', 'hours'], axis=1).reset_index().drop('index', axis=1)
    business_names = businesses['name'].values.tolist()
    businesses = preprocessing(businesses)
    
    results = {}
    for i, business in businesses.iterrows():
        results[business_names[i]] = model.predict(business.values.reshape(1, -1))[0]
    recommendations = sorted(results, key=results.get, reverse=True)
    print('The best new places for you to check out are')
    for i in range(min(len(recommendations), 10)):
        print(str(i+1) + '. ' + recommendations[i] + " - " + str(results[recommendations[i]]) + " stars predicted")
    
query('AkBtT43dYcttxQ3qOzPBAg', 'driving theaters')
# Out:
# Category: Drive-In Theater
# The best new places for you to check out are
# 1. Swap Shop - 4 stars predicted
# 2. Skyview Drive In - 4 stars predicted
# 3. Cactus Drive In Theatre - 4 stars predicted
# 4. Tibbs Drive-In Theatre - 3 stars predicted
# 5. West Wind Drive-In Santa Barbara - 3 stars predicted
# 6. Forcella BYOB - 3 stars predicted
# 7. Drive-In El Rancho - 3 stars predicted
# 8. Ruskin Family Drive-In Theater - 3 stars predicted
